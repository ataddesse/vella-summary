# %%
# !pip install chromadb
# Out:
# ...
#      ---------------------------------------- 0.0/67.3 kB ? eta -:--:--
#      ---------------------------------------- 67.3/67.3 kB 1.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/526.8 kB ? eta -:--:--
#    --------------------------- ------------ 368.6/526.8 kB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 526.8/526.8 kB 8.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/151.6 kB ? eta -:--:--
#    --------------------------- ------------ 102.4/151.6 kB ? eta -:--:--
#    -------------------------------- ------- 122.9/151.6 kB 1.4 MB/s eta 0:00:01
# ...

# %%
documents = [
    """MIME-Version: 1.0
Content-Type: multipart/alternative; boundary="----=_CityRidesPart_98765"

------=_CityRidesPart_98765
Content-Type: text/plain; charset=UTF-8
Content-Transfer-Encoding: 8bit

Hello Sarah,

Your CityRides journey was all about urban exploration! Here's a snapshot:

- From: 123 Main St, Springfield
- To: Springfield Airport
- Total Distance: 15 miles
- Duration: 35 minutes
- Fare: $22.50
- Paid via: Credit Card

We hope the ride added a touch of comfort to your day! Got a minute to rate us? support@cityrides.com.

Cheers,
The CityRides Team

------=_CityRidesPart_98765
Content-Type: text/html; charset=UTF-8
Content-Transfer-Encoding: 8bit

<html>
<head>
  <title>Your Urban Ride Summary</title>
</head>
<body style="background-color:#f7f7f7; color:#333; font-family:'Arial', sans-serif; padding:20px;">
  <h3>Hello Sarah,</h3>
  <p>Your <b>CityRides</b> journey was all about urban exploration! Here's a snapshot:</p>
  <table style="border-collapse:collapse;">
    <tr>
      <td style="padding:10px; border:1px solid #ccc;">From</td>
      <td style="padding:10px; border:1px solid #ccc;">123 Main St, Springfield</td>
    </tr>
    <tr>
      <td style="padding:10px; border:1px solid #ccc;">To</td>
      <td style="padding:10px; border:1px solid #ccc;">Springfield Airport</td>
    </tr>
    <tr>
      <td style="padding:10px; border:1px solid #ccc;">Total Distance</td>
      <td style="padding:10px; border:1px solid #ccc;">15 miles</td>
    </tr>
    <tr>
      <td style="padding:10px; border:1px solid #ccc;">Duration</td>
      <td style="padding:10px; border:1px solid #ccc;">35 minutes</td>
    </tr>
    <tr>
      <td style="padding:10px; border:1px solid #ccc;">Fare</td>
      <td style="padding:10px; border:1px solid #ccc;">$22.50</td>
    </tr>
    <tr>
      <td style="padding:10px; border:1px solid #ccc;">Paid via</td>
      <td style="padding:10px; border:1px solid #ccc;">Credit Card</td>
    </tr>
  </table>
  <p>We hope the ride added a touch of comfort to your day! Got a minute to rate us? <a href="mailto:support@cityrides.com">Email us!</a></p>
  <p>Cheers,<br/>
  <b>The CityRides Team</b></p>
</body>
</html>

------=_CityRidesPart_98765--
""",
    """
    MIME-Version: 1.0
Content-Type: multipart/alternative; boundary="----=_QuickCabPart_54321"

------=_QuickCabPart_54321
Content-Type: text/plain; charset=UTF-8
Content-Transfer-Encoding: 8bit

Hi James,

Rapid, reliable, ready—your QuickCab trip in a nutshell:

- Start: Tech Park, Innovation Road
- End: Downtown Mall
- Distance: 8 miles
- Travel Time: 20 minutes
- Cost: $16
- Payment: Apple Pay

Thanks for zipping with QuickCab! See something worth improving? help@quickcab.com.

All the best,
The QuickCab Crew

------=_QuickCabPart_54321
Content-Type: text/html; charset=UTF-8
Content-Transfer-Encoding: 8bit

<html>
<head>
  <title>QuickCab - Zoom Through Your Day!</title>
</head>
<body style="color: #0056b3; font-family: 'Verdana', sans-serif; padding: 20px; line-height: 1.6;">
  <h2>Hi James,</h2>
  <p><strong>Rapid, reliable, ready</strong>—your QuickCab trip in a nutshell:</p>
  <div style="background-color: #e6f7ff; padding: 15px; border-radius: 8px;">
    <p><strong>Start:</strong> Tech Park, Innovation Road</p>
    <p><strong>End:</strong> Downtown Mall</p>
    <p><strong>Distance:</strong> 8 miles</p>
    <p><strong>Travel Time:</strong> 20 minutes</p>
    <p><strong>Cost:</strong> $16</p>
    <p><strong>Payment:</strong> Apple Pay</p>
  </div>
  <p>Thanks for zipping with <strong>QuickCab</strong>! See something worth improving? <a href="mailto:help@quickcab.com">Let us know!</a></p>
  <p>All the best,<br/>
  <strong>The QuickCab Crew</strong></p>
</body>
</html>

------=_QuickCabPart_54321--
    """,
    """
    MIME-Version: 1.0
Content-Type: multipart/alternative; boundary="----=_MetroZoomPart_45678"

------=_MetroZoomPart_45678
Content-Type: text/plain; charset=UTF-8
Content-Transfer-Encoding: 8bit

Hey Emily,

MetroZoom whisked you away! Here's the recap of your city adventure:

- Origin: Westside Quarters
- Destination: Central Library
- Distance: 5 km
- Time: 15 minutes
- Fare: $10
- Payment: Debit Card

Feedback or suggestions? We're all ears at community@metrozoom.com.

Take care,
The MetroZoom Team

------=_MetroZoomPart_45678
Content-Type: text/html; charset=UTF-8
Content-Transfer-Encoding: 8bit

<html>
<head>
  <title>Your MetroZoom Adventure</title>
</head>
<body style="background-color: #fafafa; color: #333; font-family: 'Helvetica', sans-serif; padding: 20px;">
  <h3>Hey Emily,</h3>
  <p><strong>MetroZoom</strong> whisked you away! Here's the recap of your city adventure:</p>
  <table style="width: 100%; border: 1px solid #ddd; border-collapse: collapse; margin-top: 10px;">
    <tr>
      <td style="padding: 8px; border: 1px solid #ddd;">Origin</td>
      <td style="padding: 8px; border: 1px solid #ddd;">Westside Quarters</td>
    </tr>
    <tr>
      <td style="padding: 8px; border: 1px solid #ddd;">Destination</td>
      <td style="padding: 8px; border: 1px solid #ddd;">Central Library</td>
    </tr>
    <tr>
      <td style="padding: 8px; border: 1px solid #ddd;">Distance</td>
      <td style="padding: 8px; border: 1px solid #ddd;">5 km</td>
    </tr>
    <tr>
      <td style="padding: 8px; border: 1px solid #ddd;">Time</td>
      <td style="padding: 8px; border: 1px solid #ddd;">15 minutes</td>
    </tr>
    <tr>
      <td style="padding: 8px; border: 1px solid #ddd;">Fare</td>
      <td style="padding: 8px; border: 1px solid #ddd;">$10</td>
    </tr>
    <tr>
      <td style="padding: 8px; border: 1px solid #ddd;">Payment</td>
      <td style="padding: 8px; border: 1px solid #ddd;">Debit Card</td>
    </tr>
  </table>
  <p>Feedback or suggestions? We're all ears at <a href="mailto:community@metrozoom.com">community@metrozoom.com</a>.</p>
  <p>Take care,<br/>
  <strong>The MetroZoom Team</strong></p>
</body>
</html>

------=_MetroZoomPart_45678--
    """,
    """
    MIME-Version: 1.0
Content-Type: multipart/alternative; boundary="----=_GoDrivePart_32154"

------=_GoDrivePart_32154
Content-Type: text/plain; charset=UTF-8
Content-Transfer-Encoding: 8bit

Hello Michael,

Your GoDrive ride was the essence of city travel:

- Pickup: The Greenhouse Café
- Drop-off: Museum of Natural History
- Distance: 3 km
- Time: 10 minutes
- Fare: $8
- Payment: PayPal

Love our service or have thoughts on how we can improve? feedback@godrive.com is where you can reach us.

Warm regards,
The GoDrive Team

------=_GoDrivePart_32154
Content-Type: text/html; charset=UTF-8
Content-Transfer-Encoding: 8bit

<html>
<head>
  <title>GoDrive - Simplifying City Travel</title>
</head>
<body style="background-color: #fff3cd; color: #856404; font-family: 'Lucida Grande', sans-serif; padding: 20px;">
  <h4>Hello Michael,</h4>
  <p>Your <strong>GoDrive</strong> ride was the essence of city travel:</p>
  <div style="background-color: #fff; padding: 15px; border-left: 5px solid #ffc107; margin-bottom: 20px;">
    <p><strong>Pickup:</strong> The Greenhouse Café</p>
    <p><strong>Drop-off:</strong> Museum of Natural History</p>
    <p><strong>Distance:</strong> 3 km</p>
    <p><strong>Time:</strong> 10 minutes</p>
    <p><strong>Fare:</strong> $8</p>
    <p><strong>Payment:</strong> PayPal</p>
  </div>
  <p>Love our service or have thoughts on how we can improve? <a href="mailto:feedback@godrive.com">Let us know!</a></p>
  <p>Warm regards,<br/>
  <strong>The GoDrive Team</strong></p>
</body>
</html>

------=_GoDrivePart_32154--
    """
]

metadatas=[
    { "regex" : "Fare: \$([0-9]+\.[0-9]{2})"},
    { "regex" :'Cost: \$([0-9]+)'},
    { "regex" :"Fare: \$([0-9]+)"},
    { "regex" :"Fare: \$([0-9]+)"}
]
ids=[
    "e1","e2","e3","e4"
]

# %%
query = """
    MIME-Version: 1.0
Content-Type: multipart/alternative; boundary="----=_MetroZoomPart_78901"

------=_MetroZoomPart_78901
Content-Type: text/plain; charset=UTF-8
Content-Transfer-Encoding: 8bit

Hello Alex,

We're thrilled to have taken you on another MetroZoom journey:

- Departure: 678 Park Ave, Metro City
- Arrival: Grand Central Station
- Journey Distance: 12 km
- Travel Time: 25 minutes
- Charged Amount: $18
- Paid Through: Visa Card

Thank you for choosing MetroZoom! Any feedback? Reach us at talktous@metrozoom.com.

Best Regards,
The MetroZoom Team

------=_MetroZoomPart_78901
Content-Type: text/html; charset=UTF-8
Content-Transfer-Encoding: 8bit

<html>
<head>
  <title>Your MetroZoom Journey Details</title>
</head>
<body style="background-color: #f4f4f4; color: #444; font-family: 'Segoe UI', sans-serif; padding: 20px;">
  <h4>Hello Alex,</h4>
  <p>We're thrilled to have taken you on another <strong>MetroZoom</strong> journey:</p>
  <table style="width: 100%; border-collapse: collapse;">
    <tr style="background-color: #efefef;">
      <td style="padding: 10px; border: 1px solid #ddd;">Departure</td>
      <td style="padding: 10px; border: 1px solid #ddd;">678 Park Ave, Metro City</td>
    </tr>
    <tr>
      <td style="padding: 10px; border: 1px solid #ddd;">Arrival</td>
      <td style="padding: 10px; border: 1px solid #ddd;">Grand Central Station</td>
    </tr>
    <tr style="background-color: #efefef;">
      <td style="padding: 10px; border: 1px solid #ddd;">Journey Distance</td>
      <td style="padding: 10px; border: 1px solid #ddd;">12 km</td>
    </tr>
    <tr>
      <td style="padding: 10px; border: 1px solid #ddd;">Travel Time</td>
      <td style="padding: 10px; border: 1px solid #ddd;">25 minutes</td>
    </tr>
    <tr style="background-color: #efefef;">
      <td style="padding: 10px; border: 1px solid #ddd;">Charged Amount</td>
      <td style="padding: 10px; border: 1px solid #ddd;">$18</td>
    </tr>
    <tr>
      <td style="padding: 10px; border: 1px solid #ddd;">Paid Through</td>
      <td style="padding: 10px; border: 1px solid #ddd;">Visa Card</td>
    </tr>
  </table>
  <p>Thank you for choosing <strong>MetroZoom</strong>! Any feedback? Reach us at <a href="mailto:talktous@metrozoom.com">talktous@metrozoom.com</a>.</p>
  <p>Best Regards,<br/>
  <strong>The MetroZoom Team</strong></p>
</body>
</html>

------=_MetroZoomPart_78901--

    """

# %%
import chromadb

client = chromadb.Client()

collection = client.create_collection("email")

collection.add(
    documents=documents,
    metadatas=metadatas,
    ids=ids
)
# Out:
# C:\Users\nothe\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:12<00:00, 6.63MiB/s]

# %%
results = collection.query(
    query_texts=[query],
    n_results=1,
)
results
# Out:
# {'ids': [['e3']],
#  'distances': [[0.2926272749900818]],
#  'metadatas': [[{'regex': 'Fare: \\$([0-9]+)'}]],
#  'embeddings': None,
# ...
